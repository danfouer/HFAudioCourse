# %% [markdown]
# # 第8单元：终点线

# %% [markdown]
# ## 恭喜

# %% [markdown]
# 您为达到这一点付出了很大的努力，我们祝贺您完成本音频课程！
#
# 在整个课程中，您获得了对音频数据的基本了解，探索了新概念，并培养了使用音频变压器的实用技能。
#
# 从通过管道处理音频数据和预训练检查点的基础知识，到构建真实世界的音频应用程序，您已经了解了如何构建不仅可以理解声音而且可以创建声音的系统。
#
# 由于这个领域充满活力且不断发展，我们鼓励您保持好奇心并不断探索新模型、研究进展和新应用。在构建您自己的新的、令人兴奋的音频应用程序时，请确保始终牢记道德含义，并仔细考虑对个人和整个社会的潜在影响。
#
# 感谢您参加本音频课程，我们希望您充分享受这种教育体验，就像我们喜欢制作它一样。欢迎您在课程 GitHub 存储库中提供反馈和贡献。
#
# 要了解如何在成功通过实践作业的情况下获得当之无愧的结业证书，请查看下一页。
#
# 最后，要与音频课程团队保持联系，您可以在 Twitter 上关注我们：

# %% [markdown]
# Maria Khalusova: @mariakhalusova
#
# Sanchit Gandhi: @sanchitgandhi99
#
# Matthijs Hollemans: @mhollemans
#
# Vaibhav (VB) Srivastav: @reach_vb

# %% [markdown]
# 保持好奇心并训练Transforms:)

# %% [markdown]
# ## 获取结业证书

# %% [markdown]
# 认证过程完全免费。
#
# 要获得结业证书：您需要通过 4 项实践作业中的 3 项。
# 要获得卓越证书：您需要通过 4 项实践作业中的 4 项。
# 每项作业的要求均在各自的单元中列出：
#
# 第 4 单元 实践
# 第 5 单元 实践
# 第 6 单元 实践
# 第 7 单元 实践
# 对于需要训练模型的作业，请确保将符合要求的模型推送到具有相关kwargs. 对于第 7 单元中的演示作业，请确保您的演示是public.
#
# 如需自我评估并查看您通过/未通过哪些单元，您可以使用以下空间：
# https://huggingface.co/spaces/MariaK/Check-my-progress-Audio-Course

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic = mpimg.imread('../images/8.1Audio Course Progress.jpg')
pic.shape
plt.imshow(pic)
plt.axis('off') 
plt.show()

# %% [markdown]
# 一旦您有资格获得证书，请前往音频课程认证空间。该空间实施额外的检查，以确保您提交的内容符合评估标准。
#
#
# 在文本字段中输入您的 Hugging Face 用户名、名字和姓氏，然后单击“检查我是否通过并获取证书”按钮。
#
# 如果您通过了 4 项实践作业中的 3 项，您将收到结业证书。如果您通过了 4 项实践作业中的 4 项，您将获得卓越证书。

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic = mpimg.imread('../images/8.2certificate.jpg')
pic.shape
plt.imshow(pic)
plt.axis('off') 
plt.show()

# %% [markdown]
# 您可以下载 pdf 格式和 png 格式的证书。请随时在 Twitter（标记我@mariakhalusova 和@huggingface）和 LinkedIn 上分享您的证书。
#
# 如果您不符合认证标准，请不要灰心！返回 “检查我的进度 - 音频课程”空间，查看您需要再次完成哪些单元才能获得证书。如果您在使用任一空间时遇到任何问题，请告诉我们！
